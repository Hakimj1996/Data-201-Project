# %% [markdown]
# <a href="https://colab.research.google.com/github/Hakimj1996/Data-201-Project/blob/main/Data_201_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries needed.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import data from csv link
df =pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
# Top 50 rows and from imported DataFrame.
df.head(50)
# Out:
#    School DBN                     School Name School Level  \
# 0      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3      01M140          P.S. 140 Nathan Straus          K-8
# 4      01M140          P.S. 140 Nathan Straus          K-8
# 5      01M140          P.S. 140 Nathan Straus          K-8
# 6      01M140          P.S. 140 Nathan Straus          K-8
# 7      01M140          P.S. 140 Nathan Straus          K-8
# 8      01M184            P.S. 184m Shuang Wen          K-8
# 9      01M184            P.S. 184m Shuang Wen          K-8
# 10     01M184            P.S. 184m Shuang Wen          K-8
# 11     01M184            P.S. 184m Shuang Wen          K-8
# 12     01M188      P.S. 188 The Island School          K-8
# 13     01M188      P.S. 188 The Island School          K-8
# 14     01M188      P.S. 188 The Island School          K-8
# ...

# %%
# last 50 rows imported from Dataframe.
df.tail(50)
# Out:
#        School DBN                         School Name     School Level  \
# 212281     84X704         KIPP Academy Charter School  K-12 all grades
# 212282     84X704         KIPP Academy Charter School  K-12 all grades
# 212283     84X704         KIPP Academy Charter School  K-12 all grades
# 212284     84X704         KIPP Academy Charter School  K-12 all grades
# 212285     84X704         KIPP Academy Charter School  K-12 all grades
# 212286     84X704         KIPP Academy Charter School  K-12 all grades
# 212287     84X704         KIPP Academy Charter School  K-12 all grades
# 212288     84X704         KIPP Academy Charter School  K-12 all grades
# 212289     84X704         KIPP Academy Charter School  K-12 all grades
# 212290     84X704         KIPP Academy Charter School  K-12 all grades
# 212291     84X704         KIPP Academy Charter School  K-12 all grades
# 212292     84X704         KIPP Academy Charter School  K-12 all grades
# ...

# %%
# Create a log of missing values in dataset.
missing_values = ['s', 'na']

# %%
#Change all missing values to nan values
df =pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv', na_values = missing_values)

# %%
# Display names of every columns.
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
# Display information about DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212331 entries, 0 to 212330
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   School DBN                   212331 non-null  object
#  1   School Name                  212331 non-null  object
#  2   School Level                 212331 non-null  object
#  3   Regents Exam                 212321 non-null  object
#  4   Year                         212331 non-null  int64
#  5   Total Tested                 212331 non-null  int64
#  6   Mean Score                   137109 non-null  float64
#  7   Number Scoring Below 65      137109 non-null  float64
#  8   Percent Scoring Below 65     137109 non-null  float64
#  9   Number Scoring 65 or Above   137109 non-null  float64
#  10  Percent Scoring 65 or Above  137109 non-null  float64
#  11  Number Scoring 80 or Above   137109 non-null  float64
# ...

# %%
# Locate School DBN in Dataframe.
df[df['School DBN'] == '01M188']
# Out:
#        School DBN                 School Name School Level  \
# 12         01M188  P.S. 188 The Island School          K-8
# 13         01M188  P.S. 188 The Island School          K-8
# 14         01M188  P.S. 188 The Island School          K-8
# 15         01M188  P.S. 188 The Island School          K-8
# 16         01M188  P.S. 188 The Island School          K-8
# 17         01M188  P.S. 188 The Island School          K-8
# 18811      01M188  P.S. 188 The Island School          K-8
# 19436      01M188  P.S. 188 The Island School          K-8
# 19496      01M188  P.S. 188 The Island School          K-8
# 19497      01M188  P.S. 188 The Island School          K-8
# 19498      01M188  P.S. 188 The Island School          K-8
# 19499      01M188  P.S. 188 The Island School          K-8
# 19500      01M188  P.S. 188 The Island School          K-8
# 19501      01M188  P.S. 188 The Island School          K-8
# 19502      01M188  P.S. 188 The Island School          K-8
# ...

# %%
# Make a new DataFrame for '01M188'
df2= df[df['School DBN'] == '01M188']

# %%
# Check new DF '01M188'
df2
# Out:
#        School DBN                 School Name School Level  \
# 12         01M188  P.S. 188 The Island School          K-8
# 13         01M188  P.S. 188 The Island School          K-8
# 14         01M188  P.S. 188 The Island School          K-8
# 15         01M188  P.S. 188 The Island School          K-8
# 16         01M188  P.S. 188 The Island School          K-8
# 17         01M188  P.S. 188 The Island School          K-8
# 18811      01M188  P.S. 188 The Island School          K-8
# 19436      01M188  P.S. 188 The Island School          K-8
# 19496      01M188  P.S. 188 The Island School          K-8
# 19497      01M188  P.S. 188 The Island School          K-8
# 19498      01M188  P.S. 188 The Island School          K-8
# 19499      01M188  P.S. 188 The Island School          K-8
# 19500      01M188  P.S. 188 The Island School          K-8
# 19501      01M188  P.S. 188 The Island School          K-8
# 19502      01M188  P.S. 188 The Island School          K-8
# ...

# %%
# Creating a third DataFrame to compare the second one to.
df3= df[df['School DBN'] == '01M292']

# %%
# Verifying that the third DataFrame was created
df3
# Out:
#        School DBN                 School Name School Level  \
# 18         01M292  Orchard Collegiate Academy  High school
# 19         01M292  Orchard Collegiate Academy  High school
# 20         01M292  Orchard Collegiate Academy  High school
# 21         01M292  Orchard Collegiate Academy  High school
# 22         01M292  Orchard Collegiate Academy  High school
# ...           ...                         ...          ...
# 140049     01M292  Orchard Collegiate Academy  High school
# 140050     01M292  Orchard Collegiate Academy  High school
# 140051     01M292  Orchard Collegiate Academy  High school
# 140052     01M292  Orchard Collegiate Academy  High school
# 140053     01M292  Orchard Collegiate Academy  High school
#
#                        Regents Exam  Year  Total Tested  Mean Score  \
# 18            Algebra2/Trigonometry  2015             5         NaN
# 19            Algebra2/Trigonometry  2016             5         NaN
# ...

# %%
# "Dual" will be both the created DataFrames combined into a new one.
Dual = pd.concat([df2, df3], ignore_index=True)

# %%
# Check new "Dual" DataFrame
Dual
# Out:
#     School DBN                 School Name School Level  \
# 0       01M188  P.S. 188 The Island School          K-8
# 1       01M188  P.S. 188 The Island School          K-8
# 2       01M188  P.S. 188 The Island School          K-8
# 3       01M188  P.S. 188 The Island School          K-8
# 4       01M188  P.S. 188 The Island School          K-8
# ..         ...                         ...          ...
# 406     01M292  Orchard Collegiate Academy  High school
# 407     01M292  Orchard Collegiate Academy  High school
# 408     01M292  Orchard Collegiate Academy  High school
# 409     01M292  Orchard Collegiate Academy  High school
# 410     01M292  Orchard Collegiate Academy  High school
#
#                     Regents Exam  Year  Total Tested  Mean Score  \
# 0            Common Core Algebra  2015            23        62.9
# 1            Common Core Algebra  2016            22        69.0
# 2            Common Core Algebra  2017            20        67.4
# ...

# %%
# Comparing the average scores for regents exam.
Dual.groupby(['Regents Exam'])['Mean Score'].count()
# Out:
# Regents Exam
# Algebra2/Trigonometry               0
# Common Core Algebra                40
# Common Core Algebra2                2
# Common Core English                28
# Common Core Geometry                4
# English                            15
# Geometry                            3
# Global History and Geography       30
# Integrated Algebra                 13
# Living Environment                 36
# Physical Settings/Chemistry         0
# Physical Settings/Earth Science    23
# U.S. History and Government        28
# Name: Mean Score, dtype: int64

# %%
# Visual Histogram of DataFrame'Dual".
Dual.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc1dab26a00>,
# ...
#       dtype=object)

# %% [markdown]
# #Arrivederci My Friends.
